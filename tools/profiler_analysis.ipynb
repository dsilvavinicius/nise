# %%
import pstats
from pstats import SortKey

# %%
profile_out = pstats.Stats("run_5_armadillo_100epochs_mc.prof")

# %%
profile_out.sort_stats(SortKey.CUMULATIVE).print_stats()
# Out:
# Fri Mar  3 21:51:44 2023    run_5_armadillo_100epochs_mc.prof
#
#          77150739 function calls (77065249 primitive calls) in 365.443 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    2886/1    0.061    0.000  365.446  365.446 {built-in method builtins.exec}
#         1    0.390    0.390  365.446  365.446 experiment_scripts/train_with_ni_dataset.py:1(<module>)
#      1384    0.036    0.000  287.198    0.208 experiment_scripts/train_with_ni_dataset.py:150(create_training_data)
#      1384    0.047    0.000  285.868    0.207 experiment_scripts/train_with_ni_dataset.py:62(sample_initial_condition)
#      4152  284.995    0.069  284.995    0.069 {built-in method torch.full}
#         1    0.035    0.035   44.177   44.177 experiment_scripts/train_with_ni_dataset.py:288(reconstruct_at_times)
#         6    1.391    0.232   44.142    7.357 /home/gschardong/projects/visgraf/i4d/meshing.py:12(create_mesh)
# ...
